# %%
import os
import shutil
import re

# --- CONFIGURATION ---
# 1. Where the messy folders are
source_root = r"D:\02-Raw_data-anat\longitudinal_freesurfer_149"

# 2. Destination for organized BIDS-like structure
dest_root = r"D:\04-Raw_fMRI"

# 3. Define the specific folder names to copy (BIDS_name: current_folder_name)
folders_to_move = {
    'anat': '02-3D_T1',
    'func': '12-fmri-MemoryTask'
}

# Options
dry_run = False  # Set True to simulate without performing copies
use_move = False  # Set True to move instead of copying

# --- THE PROCESS ---
def organize_data():
    # Loop through every folder in the source directory
    for item in os.listdir(source_root):
        source_path = os.path.join(source_root, item)

        # Skip non-folders
        if not os.path.isdir(source_path):
            continue

        # Expect folder names like: 3002498_irm_t04
        match = re.search(r"(\d+)_irm_(t\d+)", item)
        if not match:
            print(f"Skipping folder (no match): {item}")
            continue

        subject_id = match.group(1)
        session_id = match.group(2)
        print(f"Processing Subject: {subject_id}, Session: {session_id}")

        # Build BIDS-like destination path: dest/sub-<id>/ses-<session>/
        subj_folder = f"sub-{subject_id}"
        sess_folder = f"ses-{session_id}"
        base_dest_path = os.path.join(dest_root, subj_folder, sess_folder)
        os.makedirs(base_dest_path, exist_ok=True)

        for bids_modality, original_name in folders_to_move.items():
            src_modality_path = os.path.join(source_path, original_name)
            dest_modality_path = os.path.join(base_dest_path, bids_modality)

            if os.path.exists(src_modality_path):
                if os.path.exists(dest_modality_path):
                    print(f"  -> Skipping {bids_modality} (Already exists)")
                    continue

                print(f"  -> {'Would copy' if dry_run else 'Copying'} {src_modality_path} -> {dest_modality_path}")
                if dry_run:
                    continue
                try:
                    if use_move:
                        shutil.move(src_modality_path, dest_modality_path)
                    else:
                        shutil.copytree(src_modality_path, dest_modality_path)
                    print(f"  -> Done: {bids_modality}")
                except Exception as e:
                    print(f"  [!] Error copying {src_modality_path} -> {dest_modality_path}: {e}")
            else:
                print(f"  [!] Warning: Could not find '{original_name}' for {subject_id}")

if __name__ == "__main__":
    organize_data()
    print("\n--- Organization Complete ---")
# Out:
# Processing Subject: 3002498, Session: t04
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3002498_irm_t04\02-3D_T1 -> D:\04-Raw_fMRI\sub-3002498\ses-t04\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3002498_irm_t04\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-3002498\ses-t04\func
#   -> Done: func
# Processing Subject: 3002498, Session: t06
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3002498_irm_t06\02-3D_T1 -> D:\04-Raw_fMRI\sub-3002498\ses-t06\anat
#   -> Done: anat
#   [!] Warning: Could not find '12-fmri-MemoryTask' for 3002498
# Processing Subject: 3025432, Session: t02
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3025432_irm_t02\02-3D_T1 -> D:\04-Raw_fMRI\sub-3025432\ses-t02\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3025432_irm_t02\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-3025432\ses-t02\func
#   -> Done: func
# Processing Subject: 3025432, Session: t06
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3025432_irm_t06\02-3D_T1 -> D:\04-Raw_fMRI\sub-3025432\ses-t06\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3025432_irm_t06\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-3025432\ses-t06\func
#   -> Done: func
# Processing Subject: 3100205, Session: t04
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3100205_irm_t04\02-3D_T1 -> D:\04-Raw_fMRI\sub-3100205\ses-t04\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3100205_irm_t04\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-3100205\ses-t04\func
#   -> Done: func
# Processing Subject: 3100205, Session: t08
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3100205_irm_t08\02-3D_T1 -> D:\04-Raw_fMRI\sub-3100205\ses-t08\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3100205_irm_t08\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-3100205\ses-t08\func
#   -> Done: func
# Processing Subject: 3123186, Session: t02
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3123186_irm_t02\02-3D_T1 -> D:\04-Raw_fMRI\sub-3123186\ses-t02\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3123186_irm_t02\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-3123186\ses-t02\func
#   -> Done: func
# Processing Subject: 3123186, Session: t04
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3123186_irm_t04\02-3D_T1 -> D:\04-Raw_fMRI\sub-3123186\ses-t04\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3123186_irm_t04\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-3123186\ses-t04\func
#   -> Done: func
# Processing Subject: 3149469, Session: t04
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3149469_irm_t04\02-3D_T1 -> D:\04-Raw_fMRI\sub-3149469\ses-t04\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3149469_irm_t04\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-3149469\ses-t04\func
#   -> Done: func
# Processing Subject: 3149469, Session: t06
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3149469_irm_t06\02-3D_T1 -> D:\04-Raw_fMRI\sub-3149469\ses-t06\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3149469_irm_t06\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-3149469\ses-t06\func
#   -> Done: func
# Processing Subject: 3291977, Session: t06
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3291977_irm_t06\02-3D_T1 -> D:\04-Raw_fMRI\sub-3291977\ses-t06\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3291977_irm_t06\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-3291977\ses-t06\func
#   -> Done: func
# Processing Subject: 3291977, Session: t08
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3291977_irm_t08\02-3D_T1 -> D:\04-Raw_fMRI\sub-3291977\ses-t08\anat
#   -> Done: anat
#   [!] Warning: Could not find '12-fmri-MemoryTask' for 3291977
# Processing Subject: 3388201, Session: t00
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3388201_irm_t00\02-3D_T1 -> D:\04-Raw_fMRI\sub-3388201\ses-t00\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3388201_irm_t00\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-3388201\ses-t00\func
#   -> Done: func
# Processing Subject: 3388201, Session: t04
#   [!] Warning: Could not find '02-3D_T1' for 3388201
#   [!] Warning: Could not find '12-fmri-MemoryTask' for 3388201
# Processing Subject: 3572536, Session: t00
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3572536_irm_t00\02-3D_T1 -> D:\04-Raw_fMRI\sub-3572536\ses-t00\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3572536_irm_t00\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-3572536\ses-t00\func
#   -> Done: func
# Processing Subject: 3572536, Session: t02
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3572536_irm_t02\02-3D_T1 -> D:\04-Raw_fMRI\sub-3572536\ses-t02\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3572536_irm_t02\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-3572536\ses-t02\func
#   -> Done: func
# Processing Subject: 3634853, Session: t00
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3634853_irm_t00\02-3D_T1 -> D:\04-Raw_fMRI\sub-3634853\ses-t00\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3634853_irm_t00\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-3634853\ses-t00\func
#   -> Done: func
# Processing Subject: 3634853, Session: t02
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3634853_irm_t02\02-3D_T1 -> D:\04-Raw_fMRI\sub-3634853\ses-t02\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3634853_irm_t02\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-3634853\ses-t02\func
#   -> Done: func
# Processing Subject: 3656304, Session: t00
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3656304_irm_t00\02-3D_T1 -> D:\04-Raw_fMRI\sub-3656304\ses-t00\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3656304_irm_t00\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-3656304\ses-t00\func
#   -> Done: func
# Processing Subject: 3656304, Session: t02
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3656304_irm_t02\02-3D_T1 -> D:\04-Raw_fMRI\sub-3656304\ses-t02\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3656304_irm_t02\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-3656304\ses-t02\func
#   -> Done: func
# Processing Subject: 3750063, Session: t02
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3750063_irm_t02\02-3D_T1 -> D:\04-Raw_fMRI\sub-3750063\ses-t02\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3750063_irm_t02\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-3750063\ses-t02\func
#   -> Done: func
# Processing Subject: 3750063, Session: t04
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3750063_irm_t04\02-3D_T1 -> D:\04-Raw_fMRI\sub-3750063\ses-t04\anat
#   -> Done: anat
#   [!] Warning: Could not find '12-fmri-MemoryTask' for 3750063
# Processing Subject: 3886505, Session: t02
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3886505_irm_t02\02-3D_T1 -> D:\04-Raw_fMRI\sub-3886505\ses-t02\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3886505_irm_t02\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-3886505\ses-t02\func
#   -> Done: func
# Processing Subject: 3886505, Session: t04
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3886505_irm_t04\02-3D_T1 -> D:\04-Raw_fMRI\sub-3886505\ses-t04\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3886505_irm_t04\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-3886505\ses-t04\func
#   -> Done: func
# Processing Subject: 4042361, Session: t02
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4042361_irm_t02\02-3D_T1 -> D:\04-Raw_fMRI\sub-4042361\ses-t02\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4042361_irm_t02\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-4042361\ses-t02\func
#   -> Done: func
# Processing Subject: 4042361, Session: t04
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4042361_irm_t04\02-3D_T1 -> D:\04-Raw_fMRI\sub-4042361\ses-t04\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4042361_irm_t04\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-4042361\ses-t04\func
#   -> Done: func
# Processing Subject: 4206804, Session: t04
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4206804_irm_t04\02-3D_T1 -> D:\04-Raw_fMRI\sub-4206804\ses-t04\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4206804_irm_t04\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-4206804\ses-t04\func
#   -> Done: func
# Processing Subject: 4206804, Session: t06
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4206804_irm_t06\02-3D_T1 -> D:\04-Raw_fMRI\sub-4206804\ses-t06\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4206804_irm_t06\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-4206804\ses-t06\func
#   -> Done: func
# Processing Subject: 4209908, Session: t00
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4209908_irm_t00\02-3D_T1 -> D:\04-Raw_fMRI\sub-4209908\ses-t00\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4209908_irm_t00\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-4209908\ses-t00\func
#   -> Done: func
# Processing Subject: 4209908, Session: t02
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4209908_irm_t02\02-3D_T1 -> D:\04-Raw_fMRI\sub-4209908\ses-t02\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4209908_irm_t02\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-4209908\ses-t02\func
#   -> Done: func
# Processing Subject: 4220920, Session: t00
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4220920_irm_t00\02-3D_T1 -> D:\04-Raw_fMRI\sub-4220920\ses-t00\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4220920_irm_t00\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-4220920\ses-t00\func
#   -> Done: func
# Processing Subject: 4220920, Session: t02
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4220920_irm_t02\02-3D_T1 -> D:\04-Raw_fMRI\sub-4220920\ses-t02\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4220920_irm_t02\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-4220920\ses-t02\func
#   -> Done: func
# Processing Subject: 4273359, Session: t06
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4273359_irm_t06\02-3D_T1 -> D:\04-Raw_fMRI\sub-4273359\ses-t06\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4273359_irm_t06\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-4273359\ses-t06\func
#   -> Done: func
# Processing Subject: 4273359, Session: t08
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4273359_irm_t08\02-3D_T1 -> D:\04-Raw_fMRI\sub-4273359\ses-t08\anat
#   -> Done: anat
#   [!] Warning: Could not find '12-fmri-MemoryTask' for 4273359
# Processing Subject: 4292802, Session: t08
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4292802_irm_t08\02-3D_T1 -> D:\04-Raw_fMRI\sub-4292802\ses-t08\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4292802_irm_t08\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-4292802\ses-t08\func
#   -> Done: func
# Processing Subject: 4292802, Session: t10
#   [!] Warning: Could not find '02-3D_T1' for 4292802
#   [!] Warning: Could not find '12-fmri-MemoryTask' for 4292802
# Processing Subject: 4501657, Session: t04
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4501657_irm_t04\02-3D_T1 -> D:\04-Raw_fMRI\sub-4501657\ses-t04\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4501657_irm_t04\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-4501657\ses-t04\func
#   -> Done: func
# Processing Subject: 4501657, Session: t06
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4501657_irm_t06\02-3D_T1 -> D:\04-Raw_fMRI\sub-4501657\ses-t06\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4501657_irm_t06\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-4501657\ses-t06\func
#   -> Done: func
# Processing Subject: 4523382, Session: t00
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4523382_irm_t00\02-3D_T1 -> D:\04-Raw_fMRI\sub-4523382\ses-t00\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4523382_irm_t00\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-4523382\ses-t00\func
#   -> Done: func
# Processing Subject: 4523382, Session: t02
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4523382_irm_t02\02-3D_T1 -> D:\04-Raw_fMRI\sub-4523382\ses-t02\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4523382_irm_t02\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-4523382\ses-t02\func
#   -> Done: func
# Processing Subject: 4615221, Session: t02
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4615221_irm_t02\02-3D_T1 -> D:\04-Raw_fMRI\sub-4615221\ses-t02\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4615221_irm_t02\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-4615221\ses-t02\func
#   -> Done: func
# Processing Subject: 4615221, Session: t04
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4615221_irm_t04\02-3D_T1 -> D:\04-Raw_fMRI\sub-4615221\ses-t04\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4615221_irm_t04\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-4615221\ses-t04\func
#   -> Done: func
# Processing Subject: 4694616, Session: t02
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4694616_irm_t02\02-3D_T1 -> D:\04-Raw_fMRI\sub-4694616\ses-t02\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4694616_irm_t02\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-4694616\ses-t02\func
#   -> Done: func
# Processing Subject: 4694616, Session: t04
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4694616_irm_t04\02-3D_T1 -> D:\04-Raw_fMRI\sub-4694616\ses-t04\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4694616_irm_t04\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-4694616\ses-t04\func
#   -> Done: func
# Processing Subject: 4752214, Session: t00
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4752214_irm_t00\02-3D_T1 -> D:\04-Raw_fMRI\sub-4752214\ses-t00\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4752214_irm_t00\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-4752214\ses-t00\func
#   -> Done: func
# Processing Subject: 4752214, Session: t02
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4752214_irm_t02\02-3D_T1 -> D:\04-Raw_fMRI\sub-4752214\ses-t02\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4752214_irm_t02\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-4752214\ses-t02\func
#   -> Done: func
# Processing Subject: 4799805, Session: t06
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4799805_irm_t06\02-3D_T1 -> D:\04-Raw_fMRI\sub-4799805\ses-t06\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4799805_irm_t06\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-4799805\ses-t06\func
#   -> Done: func
# Processing Subject: 4799805, Session: t08
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4799805_irm_t08\02-3D_T1 -> D:\04-Raw_fMRI\sub-4799805\ses-t08\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4799805_irm_t08\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-4799805\ses-t08\func
#   -> Done: func
# Processing Subject: 4867946, Session: t00
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4867946_irm_t00\02-3D_T1 -> D:\04-Raw_fMRI\sub-4867946\ses-t00\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4867946_irm_t00\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-4867946\ses-t00\func
#   -> Done: func
# Processing Subject: 4867946, Session: t02
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4867946_irm_t02\02-3D_T1 -> D:\04-Raw_fMRI\sub-4867946\ses-t02\anat
#   -> Done: anat
#   [!] Warning: Could not find '12-fmri-MemoryTask' for 4867946
# Processing Subject: 4893763, Session: t04
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4893763_irm_t04\02-3D_T1 -> D:\04-Raw_fMRI\sub-4893763\ses-t04\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4893763_irm_t04\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-4893763\ses-t04\func
#   -> Done: func
# Processing Subject: 4893763, Session: t06
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4893763_irm_t06\02-3D_T1 -> D:\04-Raw_fMRI\sub-4893763\ses-t06\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\4893763_irm_t06\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-4893763\ses-t06\func
#   -> Done: func
# Processing Subject: 5028259, Session: t02
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5028259_irm_t02\02-3D_T1 -> D:\04-Raw_fMRI\sub-5028259\ses-t02\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5028259_irm_t02\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-5028259\ses-t02\func
#   -> Done: func
# Processing Subject: 5028259, Session: t04
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5028259_irm_t04\02-3D_T1 -> D:\04-Raw_fMRI\sub-5028259\ses-t04\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5028259_irm_t04\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-5028259\ses-t04\func
#   -> Done: func
# Processing Subject: 5187729, Session: t00
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5187729_irm_t00\02-3D_T1 -> D:\04-Raw_fMRI\sub-5187729\ses-t00\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5187729_irm_t00\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-5187729\ses-t00\func
#   -> Done: func
# Processing Subject: 5187729, Session: t02
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5187729_irm_t02\02-3D_T1 -> D:\04-Raw_fMRI\sub-5187729\ses-t02\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5187729_irm_t02\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-5187729\ses-t02\func
#   -> Done: func
# Processing Subject: 5195562, Session: t00
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5195562_irm_t00\02-3D_T1 -> D:\04-Raw_fMRI\sub-5195562\ses-t00\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5195562_irm_t00\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-5195562\ses-t00\func
#   -> Done: func
# Processing Subject: 5195562, Session: t02
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5195562_irm_t02\02-3D_T1 -> D:\04-Raw_fMRI\sub-5195562\ses-t02\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5195562_irm_t02\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-5195562\ses-t02\func
#   -> Done: func
# Processing Subject: 5199730, Session: t00
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5199730_irm_t00\02-3D_T1 -> D:\04-Raw_fMRI\sub-5199730\ses-t00\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5199730_irm_t00\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-5199730\ses-t00\func
#   -> Done: func
# Processing Subject: 5199730, Session: t02
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5199730_irm_t02\02-3D_T1 -> D:\04-Raw_fMRI\sub-5199730\ses-t02\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5199730_irm_t02\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-5199730\ses-t02\func
#   -> Done: func
# Processing Subject: 5213989, Session: t00
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5213989_irm_t00\02-3D_T1 -> D:\04-Raw_fMRI\sub-5213989\ses-t00\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5213989_irm_t00\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-5213989\ses-t00\func
#   -> Done: func
# Processing Subject: 5213989, Session: t02
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5213989_irm_t02\02-3D_T1 -> D:\04-Raw_fMRI\sub-5213989\ses-t02\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5213989_irm_t02\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-5213989\ses-t02\func
#   -> Done: func
# Processing Subject: 5237572, Session: t06
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5237572_irm_t06\02-3D_T1 -> D:\04-Raw_fMRI\sub-5237572\ses-t06\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5237572_irm_t06\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-5237572\ses-t06\func
#   -> Done: func
# Processing Subject: 5329975, Session: t00
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5329975_irm_t00\02-3D_T1 -> D:\04-Raw_fMRI\sub-5329975\ses-t00\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5329975_irm_t00\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-5329975\ses-t00\func
#   -> Done: func
# Processing Subject: 5329975, Session: t02
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5329975_irm_t02\02-3D_T1 -> D:\04-Raw_fMRI\sub-5329975\ses-t02\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5329975_irm_t02\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-5329975\ses-t02\func
#   -> Done: func
# Processing Subject: 5381177, Session: t04
#   [!] Warning: Could not find '02-3D_T1' for 5381177
#   [!] Warning: Could not find '12-fmri-MemoryTask' for 5381177
# Processing Subject: 5381177, Session: t06
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5381177_irm_t06\02-3D_T1 -> D:\04-Raw_fMRI\sub-5381177\ses-t06\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5381177_irm_t06\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-5381177\ses-t06\func
#   -> Done: func
# Processing Subject: 5413210, Session: t00
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5413210_irm_t00\02-3D_T1 -> D:\04-Raw_fMRI\sub-5413210\ses-t00\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5413210_irm_t00\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-5413210\ses-t00\func
#   -> Done: func
# Processing Subject: 5413210, Session: t02
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5413210_irm_t02\02-3D_T1 -> D:\04-Raw_fMRI\sub-5413210\ses-t02\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5413210_irm_t02\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-5413210\ses-t02\func
#   -> Done: func
# Processing Subject: 5477234, Session: t06
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5477234_irm_t06\02-3D_T1 -> D:\04-Raw_fMRI\sub-5477234\ses-t06\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5477234_irm_t06\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-5477234\ses-t06\func
#   -> Done: func
# Processing Subject: 5477234, Session: t08
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5477234_irm_t08\02-3D_T1 -> D:\04-Raw_fMRI\sub-5477234\ses-t08\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5477234_irm_t08\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-5477234\ses-t08\func
#   -> Done: func
# Processing Subject: 5585902, Session: t06
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5585902_irm_t06\02-3D_T1 -> D:\04-Raw_fMRI\sub-5585902\ses-t06\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5585902_irm_t06\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-5585902\ses-t06\func
#   -> Done: func
# Processing Subject: 5585902, Session: t08
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5585902_irm_t08\02-3D_T1 -> D:\04-Raw_fMRI\sub-5585902\ses-t08\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5585902_irm_t08\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-5585902\ses-t08\func
#   -> Done: func
# Processing Subject: 5595871, Session: t02
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5595871_irm_t02\02-3D_T1 -> D:\04-Raw_fMRI\sub-5595871\ses-t02\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5595871_irm_t02\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-5595871\ses-t02\func
#   -> Done: func
# Processing Subject: 5701721, Session: t06
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5701721_irm_t06\02-3D_T1 -> D:\04-Raw_fMRI\sub-5701721\ses-t06\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5701721_irm_t06\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-5701721\ses-t06\func
#   -> Done: func
# Processing Subject: 5701721, Session: t08
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5701721_irm_t08\02-3D_T1 -> D:\04-Raw_fMRI\sub-5701721\ses-t08\anat
#   -> Done: anat
#   [!] Warning: Could not find '12-fmri-MemoryTask' for 5701721
# Processing Subject: 5760364, Session: t06
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5760364_irm_t06\02-3D_T1 -> D:\04-Raw_fMRI\sub-5760364\ses-t06\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5760364_irm_t06\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-5760364\ses-t06\func
#   -> Done: func
# Processing Subject: 5760364, Session: t08
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5760364_irm_t08\02-3D_T1 -> D:\04-Raw_fMRI\sub-5760364\ses-t08\anat
#   -> Done: anat
#   [!] Warning: Could not find '12-fmri-MemoryTask' for 5760364
# Processing Subject: 5788838, Session: t04
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5788838_irm_t04\02-3D_T1 -> D:\04-Raw_fMRI\sub-5788838\ses-t04\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5788838_irm_t04\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-5788838\ses-t04\func
#   -> Done: func
# Processing Subject: 5788838, Session: t06
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5788838_irm_t06\02-3D_T1 -> D:\04-Raw_fMRI\sub-5788838\ses-t06\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5788838_irm_t06\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-5788838\ses-t06\func
#   -> Done: func
# Processing Subject: 5887249, Session: t06
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5887249_irm_t06\02-3D_T1 -> D:\04-Raw_fMRI\sub-5887249\ses-t06\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5887249_irm_t06\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-5887249\ses-t06\func
#   -> Done: func
# Processing Subject: 5887249, Session: t08
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5887249_irm_t08\02-3D_T1 -> D:\04-Raw_fMRI\sub-5887249\ses-t08\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5887249_irm_t08\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-5887249\ses-t08\func
#   -> Done: func
# Processing Subject: 5909569, Session: t00
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5909569_irm_t00\02-3D_T1 -> D:\04-Raw_fMRI\sub-5909569\ses-t00\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5909569_irm_t00\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-5909569\ses-t00\func
#   -> Done: func
# Processing Subject: 5909569, Session: t02
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5909569_irm_t02\02-3D_T1 -> D:\04-Raw_fMRI\sub-5909569\ses-t02\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\5909569_irm_t02\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-5909569\ses-t02\func
#   -> Done: func
# Processing Subject: 6121388, Session: t04
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\6121388_irm_t04\02-3D_T1 -> D:\04-Raw_fMRI\sub-6121388\ses-t04\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\6121388_irm_t04\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-6121388\ses-t04\func
#   -> Done: func
# Processing Subject: 6121388, Session: t06
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\6121388_irm_t06\02-3D_T1 -> D:\04-Raw_fMRI\sub-6121388\ses-t06\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\6121388_irm_t06\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-6121388\ses-t06\func
#   -> Done: func
# Processing Subject: 6144194, Session: t02
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\6144194_irm_t02\02-3D_T1 -> D:\04-Raw_fMRI\sub-6144194\ses-t02\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\6144194_irm_t02\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-6144194\ses-t02\func
#   -> Done: func
# Processing Subject: 6144194, Session: t04
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\6144194_irm_t04\02-3D_T1 -> D:\04-Raw_fMRI\sub-6144194\ses-t04\anat
#   -> Done: anat
#   [!] Warning: Could not find '12-fmri-MemoryTask' for 6144194
# Processing Subject: 6258913, Session: t02
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\6258913_irm_t02\02-3D_T1 -> D:\04-Raw_fMRI\sub-6258913\ses-t02\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\6258913_irm_t02\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-6258913\ses-t02\func
#   -> Done: func
# Processing Subject: 6272511, Session: t02
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\6272511_irm_t02\02-3D_T1 -> D:\04-Raw_fMRI\sub-6272511\ses-t02\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\6272511_irm_t02\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-6272511\ses-t02\func
#   -> Done: func
# Processing Subject: 6272511, Session: t06
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\6272511_irm_t06\02-3D_T1 -> D:\04-Raw_fMRI\sub-6272511\ses-t06\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\6272511_irm_t06\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-6272511\ses-t06\func
#   -> Done: func
# Processing Subject: 6371164, Session: t00
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\6371164_irm_t00\02-3D_T1 -> D:\04-Raw_fMRI\sub-6371164\ses-t00\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\6371164_irm_t00\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-6371164\ses-t00\func
#   -> Done: func
# Processing Subject: 6371164, Session: t02
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\6371164_irm_t02\02-3D_T1 -> D:\04-Raw_fMRI\sub-6371164\ses-t02\anat
#   -> Done: anat
#   [!] Warning: Could not find '12-fmri-MemoryTask' for 6371164
# Processing Subject: 6412865, Session: t00
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\6412865_irm_t00\02-3D_T1 -> D:\04-Raw_fMRI\sub-6412865\ses-t00\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\6412865_irm_t00\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-6412865\ses-t00\func
#   -> Done: func
# Processing Subject: 6412865, Session: t02
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\6412865_irm_t02\02-3D_T1 -> D:\04-Raw_fMRI\sub-6412865\ses-t02\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\6412865_irm_t02\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-6412865\ses-t02\func
#   -> Done: func
# Processing Subject: 6417837, Session: t04
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\6417837_irm_t04\02-3D_T1 -> D:\04-Raw_fMRI\sub-6417837\ses-t04\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\6417837_irm_t04\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-6417837\ses-t04\func
#   -> Done: func
# Processing Subject: 6417837, Session: t06
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\6417837_irm_t06\02-3D_T1 -> D:\04-Raw_fMRI\sub-6417837\ses-t06\anat
#   -> Done: anat
#   [!] Warning: Could not find '12-fmri-MemoryTask' for 6417837
# Processing Subject: 6477990, Session: t00
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\6477990_irm_t00\02-3D_T1 -> D:\04-Raw_fMRI\sub-6477990\ses-t00\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\6477990_irm_t00\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-6477990\ses-t00\func
#   -> Done: func
# Processing Subject: 6477990, Session: t02
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\6477990_irm_t02\02-3D_T1 -> D:\04-Raw_fMRI\sub-6477990\ses-t02\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\6477990_irm_t02\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-6477990\ses-t02\func
#   -> Done: func
# Processing Subject: 6633412, Session: t00
#   [!] Warning: Could not find '02-3D_T1' for 6633412
#   [!] Warning: Could not find '12-fmri-MemoryTask' for 6633412
# Processing Subject: 6633412, Session: t06
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\6633412_irm_t06\02-3D_T1 -> D:\04-Raw_fMRI\sub-6633412\ses-t06\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\6633412_irm_t06\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-6633412\ses-t06\func
#   -> Done: func
# Processing Subject: 6714520, Session: t00
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\6714520_irm_t00\02-3D_T1 -> D:\04-Raw_fMRI\sub-6714520\ses-t00\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\6714520_irm_t00\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-6714520\ses-t00\func
#   -> Done: func
# Processing Subject: 6765420, Session: t00
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\6765420_irm_t00\02-3D_T1 -> D:\04-Raw_fMRI\sub-6765420\ses-t00\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\6765420_irm_t00\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-6765420\ses-t00\func
#   -> Done: func
# Processing Subject: 6765420, Session: t02
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\6765420_irm_t02\02-3D_T1 -> D:\04-Raw_fMRI\sub-6765420\ses-t02\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\6765420_irm_t02\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-6765420\ses-t02\func
#   -> Done: func
# Processing Subject: 7344500, Session: t00
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\7344500_irm_t00\02-3D_T1 -> D:\04-Raw_fMRI\sub-7344500\ses-t00\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\7344500_irm_t00\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-7344500\ses-t00\func
#   -> Done: func
# Processing Subject: 7344500, Session: t02
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\7344500_irm_t02\02-3D_T1 -> D:\04-Raw_fMRI\sub-7344500\ses-t02\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\7344500_irm_t02\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-7344500\ses-t02\func
#   -> Done: func
# Processing Subject: 7459501, Session: t06
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\7459501_irm_t06\02-3D_T1 -> D:\04-Raw_fMRI\sub-7459501\ses-t06\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\7459501_irm_t06\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-7459501\ses-t06\func
#   -> Done: func
# Processing Subject: 7459501, Session: t08
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\7459501_irm_t08\02-3D_T1 -> D:\04-Raw_fMRI\sub-7459501\ses-t08\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\7459501_irm_t08\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-7459501\ses-t08\func
#   -> Done: func
# Processing Subject: 7485585, Session: t04
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\7485585_irm_t04\02-3D_T1 -> D:\04-Raw_fMRI\sub-7485585\ses-t04\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\7485585_irm_t04\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-7485585\ses-t04\func
#   -> Done: func
# Processing Subject: 7485585, Session: t06
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\7485585_irm_t06\02-3D_T1 -> D:\04-Raw_fMRI\sub-7485585\ses-t06\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\7485585_irm_t06\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-7485585\ses-t06\func
#   -> Done: func
# Processing Subject: 7573547, Session: t00
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\7573547_irm_t00\02-3D_T1 -> D:\04-Raw_fMRI\sub-7573547\ses-t00\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\7573547_irm_t00\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-7573547\ses-t00\func
#   -> Done: func
# Processing Subject: 7573547, Session: t02
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\7573547_irm_t02\02-3D_T1 -> D:\04-Raw_fMRI\sub-7573547\ses-t02\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\7573547_irm_t02\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-7573547\ses-t02\func
#   -> Done: func
# Processing Subject: 7725018, Session: t02
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\7725018_irm_t02\02-3D_T1 -> D:\04-Raw_fMRI\sub-7725018\ses-t02\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\7725018_irm_t02\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-7725018\ses-t02\func
#   -> Done: func
# Processing Subject: 7725018, Session: t04
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\7725018_irm_t04\02-3D_T1 -> D:\04-Raw_fMRI\sub-7725018\ses-t04\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\7725018_irm_t04\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-7725018\ses-t04\func
#   -> Done: func
# Processing Subject: 7853010, Session: t04
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\7853010_irm_t04\02-3D_T1 -> D:\04-Raw_fMRI\sub-7853010\ses-t04\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\7853010_irm_t04\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-7853010\ses-t04\func
#   -> Done: func
# Processing Subject: 7853010, Session: t06
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\7853010_irm_t06\02-3D_T1 -> D:\04-Raw_fMRI\sub-7853010\ses-t06\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\7853010_irm_t06\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-7853010\ses-t06\func
#   -> Done: func
# Processing Subject: 7948407, Session: t02
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\7948407_irm_t02\02-3D_T1 -> D:\04-Raw_fMRI\sub-7948407\ses-t02\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\7948407_irm_t02\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-7948407\ses-t02\func
#   -> Done: func
# Processing Subject: 7948407, Session: t04
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\7948407_irm_t04\02-3D_T1 -> D:\04-Raw_fMRI\sub-7948407\ses-t04\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\7948407_irm_t04\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-7948407\ses-t04\func
#   -> Done: func
# Processing Subject: 8000280, Session: t00
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\8000280_irm_t00\02-3D_T1 -> D:\04-Raw_fMRI\sub-8000280\ses-t00\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\8000280_irm_t00\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-8000280\ses-t00\func
#   -> Done: func
# Processing Subject: 8000280, Session: t02
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\8000280_irm_t02\02-3D_T1 -> D:\04-Raw_fMRI\sub-8000280\ses-t02\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\8000280_irm_t02\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-8000280\ses-t02\func
#   -> Done: func
# Processing Subject: 8060583, Session: t00
#   [!] Warning: Could not find '02-3D_T1' for 8060583
#   [!] Warning: Could not find '12-fmri-MemoryTask' for 8060583
# Processing Subject: 8060583, Session: t06
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\8060583_irm_t06\02-3D_T1 -> D:\04-Raw_fMRI\sub-8060583\ses-t06\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\8060583_irm_t06\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-8060583\ses-t06\func
#   -> Done: func
# Processing Subject: 8192087, Session: t04
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\8192087_irm_t04\02-3D_T1 -> D:\04-Raw_fMRI\sub-8192087\ses-t04\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\8192087_irm_t04\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-8192087\ses-t04\func
#   -> Done: func
# Processing Subject: 8192087, Session: t06
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\8192087_irm_t06\02-3D_T1 -> D:\04-Raw_fMRI\sub-8192087\ses-t06\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\8192087_irm_t06\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-8192087\ses-t06\func
#   -> Done: func
# Processing Subject: 8193847, Session: t00
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\8193847_irm_t00\02-3D_T1 -> D:\04-Raw_fMRI\sub-8193847\ses-t00\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\8193847_irm_t00\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-8193847\ses-t00\func
#   -> Done: func
# Processing Subject: 8193847, Session: t02
#   [!] Warning: Could not find '02-3D_T1' for 8193847
#   [!] Warning: Could not find '12-fmri-MemoryTask' for 8193847
# Processing Subject: 8210381, Session: t00
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\8210381_irm_t00\02-3D_T1 -> D:\04-Raw_fMRI\sub-8210381\ses-t00\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\8210381_irm_t00\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-8210381\ses-t00\func
#   -> Done: func
# Processing Subject: 8210381, Session: t02
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\8210381_irm_t02\02-3D_T1 -> D:\04-Raw_fMRI\sub-8210381\ses-t02\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\8210381_irm_t02\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-8210381\ses-t02\func
#   -> Done: func
# Processing Subject: 8212673, Session: t04
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\8212673_irm_t04\02-3D_T1 -> D:\04-Raw_fMRI\sub-8212673\ses-t04\anat
#   -> Done: anat
#   [!] Warning: Could not find '12-fmri-MemoryTask' for 8212673
# Processing Subject: 8212673, Session: t06
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\8212673_irm_t06\02-3D_T1 -> D:\04-Raw_fMRI\sub-8212673\ses-t06\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\8212673_irm_t06\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-8212673\ses-t06\func
#   -> Done: func
# Processing Subject: 8352837, Session: t00
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\8352837_irm_t00\02-3D_T1 -> D:\04-Raw_fMRI\sub-8352837\ses-t00\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\8352837_irm_t00\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-8352837\ses-t00\func
#   -> Done: func
# Processing Subject: 8352837, Session: t02
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\8352837_irm_t02\02-3D_T1 -> D:\04-Raw_fMRI\sub-8352837\ses-t02\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\8352837_irm_t02\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-8352837\ses-t02\func
#   -> Done: func
# Processing Subject: 8697472, Session: t00
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\8697472_irm_t00\02-3D_T1 -> D:\04-Raw_fMRI\sub-8697472\ses-t00\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\8697472_irm_t00\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-8697472\ses-t00\func
#   -> Done: func
# Processing Subject: 8697472, Session: t02
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\8697472_irm_t02\02-3D_T1 -> D:\04-Raw_fMRI\sub-8697472\ses-t02\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\8697472_irm_t02\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-8697472\ses-t02\func
#   -> Done: func
# Processing Subject: 8782079, Session: t04
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\8782079_irm_t04\02-3D_T1 -> D:\04-Raw_fMRI\sub-8782079\ses-t04\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\8782079_irm_t04\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-8782079\ses-t04\func
#   -> Done: func
# Processing Subject: 8782079, Session: t06
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\8782079_irm_t06\02-3D_T1 -> D:\04-Raw_fMRI\sub-8782079\ses-t06\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\8782079_irm_t06\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-8782079\ses-t06\func
#   -> Done: func
# Processing Subject: 8840385, Session: t00
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\8840385_irm_t00\02-3D_T1 -> D:\04-Raw_fMRI\sub-8840385\ses-t00\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\8840385_irm_t00\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-8840385\ses-t00\func
#   -> Done: func
# Processing Subject: 8840385, Session: t02
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\8840385_irm_t02\02-3D_T1 -> D:\04-Raw_fMRI\sub-8840385\ses-t02\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\8840385_irm_t02\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-8840385\ses-t02\func
#   -> Done: func
# Processing Subject: 8874623, Session: t06
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\8874623_irm_t06\02-3D_T1 -> D:\04-Raw_fMRI\sub-8874623\ses-t06\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\8874623_irm_t06\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-8874623\ses-t06\func
#   -> Done: func
# Processing Subject: 8874623, Session: t08
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\8874623_irm_t08\02-3D_T1 -> D:\04-Raw_fMRI\sub-8874623\ses-t08\anat
#   -> Done: anat
#   [!] Warning: Could not find '12-fmri-MemoryTask' for 8874623
# Processing Subject: 8980899, Session: t06
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\8980899_irm_t06\02-3D_T1 -> D:\04-Raw_fMRI\sub-8980899\ses-t06\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\8980899_irm_t06\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-8980899\ses-t06\func
#   -> Done: func
# Processing Subject: 8980899, Session: t08
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\8980899_irm_t08\02-3D_T1 -> D:\04-Raw_fMRI\sub-8980899\ses-t08\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\8980899_irm_t08\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-8980899\ses-t08\func
#   -> Done: func
# Processing Subject: 9234862, Session: t02
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\9234862_irm_t02\02-3D_T1 -> D:\04-Raw_fMRI\sub-9234862\ses-t02\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\9234862_irm_t02\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-9234862\ses-t02\func
#   -> Done: func
# Processing Subject: 9234862, Session: t06
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\9234862_irm_t06\02-3D_T1 -> D:\04-Raw_fMRI\sub-9234862\ses-t06\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\9234862_irm_t06\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-9234862\ses-t06\func
#   -> Done: func
# Skipping folder (no match): nifti
# Skipping folder (no match): reconall_output
# Skipping folder (no match): longi_output
# Processing Subject: 3420680, Session: t06
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3420680_irm_t06\02-3D_T1 -> D:\04-Raw_fMRI\sub-3420680\ses-t06\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3420680_irm_t06\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-3420680\ses-t06\func
#   -> Done: func
# Processing Subject: 3420680, Session: t08
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3420680_irm_t08\02-3D_T1 -> D:\04-Raw_fMRI\sub-3420680\ses-t08\anat
#   -> Done: anat
#   -> Copying D:\02-Raw_data-anat\longitudinal_freesurfer_149\3420680_irm_t08\12-fmri-MemoryTask -> D:\04-Raw_fMRI\sub-3420680\ses-t08\func
#   -> Done: func
#
# --- Organization Complete ---
