# %%
# convert everything under /path/to/DICOMs into gzipped NIfTIs in /out/dir
# produce uncompressed NIfTIs
# !dcm2niix -z n "E:\02-Raw_data-anat\longitudinal_freesurfer_149\3002498_irm_t04\02-3D_T1"
# Out:
# Compression will be faster with C:\Users\okkam\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\dcm2niix\pigz.exe in the same folder as the executable
# Chris Rorden's dcm2niiX version v1.0.20250505  MSC1943  (64-bit Windows)
# Found 192 DICOM file(s)
# Convert 192 DICOM as E:\02-Raw_data-anat\longitudinal_freesurfer_149\3002498_irm_t04\02-3D_T1\02-3D_T1_3D_T1_20190527141834_2 (256x256x192x1)
# Conversion required 4.848000 seconds.

# %%
#Convert for one subject 
# !dcm2niix -z n "E:\02-Raw_data-anat\longitudinal_freesurfer_149\3002498_irm_t04\02-3D_T1"
# !dcm2niix -z n "E:\02-Raw_data-anat\longitudinal_freesurfer_149\3002498_irm_t04\12-fmri-MemoryTask"
# !dcm2niix -z n "E:\02-Raw_data-anat\longitudinal_freesurfer_149\3002498_irm_t04\14-fmri_fieldmap_gre_field_mapping"
# !dcm2niix -z n "E:\02-Raw_data-anat\longitudinal_freesurfer_149\3002498_irm_t04\15-fmri_fieldmap_gre_field_mapping"

#and T2 for this subject
# !dcm2niix -z n "E:\02-Raw_data-anat\longitudinal_freesurfer_149\3002498_irm_t06\02-3D_T1"
# !dcm2niix -z n "E:\02-Raw_data-anat\longitudinal_freesurfer_149\3002498_irm_t06\13-fmri-MemoryTask"
# !dcm2niix -z n "E:\02-Raw_data-anat\longitudinal_freesurfer_149\3002498_irm_t06\15-fmri_fieldmap_gre_field_mapping"
# !dcm2niix -z n "E:\02-Raw_data-anat\longitudinal_freesurfer_149\3002498_irm_t06\16-fmri_fieldmap_gre_field_mapping"
# Out:
# Compression will be faster with C:\Users\okkam\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\dcm2niix\pigz.exe in the same folder as the executable
# Chris Rorden's dcm2niiX version v1.0.20250505  MSC1943  (64-bit Windows)
# Found 192 DICOM file(s)
# Convert 192 DICOM as E:\02-Raw_data-anat\longitudinal_freesurfer_149\3002498_irm_t04\02-3D_T1\02-3D_T1_3D_T1_20190527141834_2a (256x256x192x1)
# Conversion required 5.342000 seconds.
# Compression will be faster with C:\Users\okkam\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\dcm2niix\pigz.exe in the same folder as the executable
# Chris Rorden's dcm2niiX version v1.0.20250505  MSC1943  (64-bit Windows)
# Found 310 DICOM file(s)
# ...
